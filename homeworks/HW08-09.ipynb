# %% [markdown]
# #### Импорты, seed и устройство

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms

import numpy as np
import matplotlib.pyplot as plt
import json
import csv
import os

SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cpu

# %% [markdown]
# #### Данные и DataLoader

# %%
transform = transforms.ToTensor()

def get_emnist_dataloaders(batch_size=128, val_ratio=0.2, seed=SEED):
    train_full = datasets.EMNIST(
        root="./data",
        split="balanced",
        train=True,
        download=True,
        transform=transform
    )
    test = datasets.EMNIST(
        root="./data",
        split="balanced",
        train=False,
        download=True,
        transform=transform
    )

    val_size = int(len(train_full) * val_ratio)
    train_size = len(train_full) - val_size

    train_ds, val_ds = random_split(
        train_full,
        [train_size, val_size],
        generator=torch.Generator().manual_seed(seed)
    )

    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_ds, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test, batch_size=batch_size, shuffle=False)

    return train_loader, val_loader, test_loader

train_loader, val_loader, test_loader = get_emnist_dataloaders()

# %% [markdown]
# #### MLP-модель

# %%
class MLP(nn.Module):
    def __init__(self, hidden_sizes=(512, 256), dropout_p=0.0, use_bn=False):
        super().__init__()

        layers = [nn.Flatten()] 

        in_features = 28 * 28
        for h in hidden_sizes:
            layers.append(nn.Linear(in_features, h))
            if use_bn:
                layers.append(nn.BatchNorm1d(h))
            layers.append(nn.ReLU())
            if dropout_p > 0:
                layers.append(nn.Dropout(dropout_p))
            in_features = h

        layers.append(nn.Linear(in_features, 47)) 

        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# Accuracy

# %%
def accuracy_from_logits(logits, y):
    preds = logits.argmax(dim=1)
    return (preds == y).float().mean().item()

# %% [markdown]
# Train и Evaluate

# %%
def train_one_epoch(model, loader, optimizer, criterion):
    model.train()
    total_loss = 0.0
    total_correct = 0
    total_samples = 0

    for x, y in loader:
        x, y = x.to(device), y.to(device)

        optimizer.zero_grad()
        logits = model(x)
        loss = criterion(logits, y)
        loss.backward()
        optimizer.step()

        batch_size = x.size(0)
        total_loss += loss.item() * batch_size
        total_correct += (logits.argmax(dim=1) == y).sum().item()
        total_samples += batch_size

    return total_loss / total_samples, total_correct / total_samples


def evaluate(model, loader, criterion):
    model.eval()
    total_loss = 0.0
    total_correct = 0
    total_samples = 0

    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            logits = model(x)
            loss = criterion(logits, y)

            batch_size = x.size(0)
            total_loss += loss.item() * batch_size
            total_correct += (logits.argmax(dim=1) == y).sum().item()
            total_samples += batch_size

    return total_loss / total_samples, total_correct / total_samples

# %% [markdown]
# #### Часть A (S08)

# %% [markdown]
# Функция экперимента

# %%
def run_experiment(
    exp_id,
    dropout=0.0,
    use_bn=False,
    optimizer_name="Adam",
    lr=1e-3,
    momentum=0.0,
    weight_decay=0.0,
    max_epochs=20,
    early_stopping=False,
    patience=5,
):
    print(f"\n=== {exp_id} ===")
    print(f"dropout={dropout}, bn={use_bn}, opt={optimizer_name}, lr={lr}, "
          f"momentum={momentum}, wd={weight_decay}, early_stopping={early_stopping}")

    model = MLP(dropout_p=dropout, use_bn=use_bn).to(device)
    criterion = nn.CrossEntropyLoss()

    if optimizer_name == "Adam":
        optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    else:
        optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=weight_decay)

    history = {
        "train_loss": [],
        "val_loss": [],
        "train_acc": [],
        "val_acc": [],
    }

    best_val_acc = 0.0
    best_state = None
    wait = 0

    for epoch in range(1, max_epochs + 1):
        train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, criterion)
        val_loss, val_acc = evaluate(model, val_loader, criterion)

        history["train_loss"].append(train_loss)
        history["val_loss"].append(val_loss)
        history["train_acc"].append(train_acc)
        history["val_acc"].append(val_acc)

        print(f"Epoch {epoch:02d}: "
              f"train_loss={train_loss:.4f}, val_loss={val_loss:.4f}, "
              f"train_acc={train_acc:.4f}, val_acc={val_acc:.4f}")

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_state = model.state_dict()
            wait = 0
        else:
            wait += 1

        if early_stopping and wait >= patience:
            print(f"Early stopping at epoch {epoch} (patience={patience})")
            break

    return best_val_acc, best_state, history

# %% [markdown]
# E1–E4

# %%
results = {}

results["E1"] = run_experiment("E1", dropout=0.0, use_bn=False)
results["E2"] = run_experiment("E2", dropout=0.3, use_bn=False)
results["E3"] = run_experiment("E3", dropout=0.0, use_bn=True)

best_reg_exp = max(["E2", "E3"], key=lambda e: results[e][0])
print("Лучший эксперимент регуляризации:", best_reg_exp)

if best_reg_exp == "E2":
    results["E4"] = run_experiment("E4", dropout=0.3, use_bn=False, early_stopping=True)
else:
    results["E4"] = run_experiment("E4", dropout=0.0, use_bn=True, early_stopping=True)

best_model_state = results["E4"][1]
torch.save(best_model_state, "artifacts/best_model.pt")
# Out:
# === E1 ===
# dropout=0.0, bn=False, opt=Adam, lr=0.001, momentum=0.0, wd=0.0, early_stopping=False
# Epoch 01: train_loss=1.0925, val_loss=0.6929, train_acc=0.6799, val_acc=0.7824
# Epoch 02: train_loss=0.5838, val_loss=0.5482, train_acc=0.8097, val_acc=0.8219
# Epoch 03: train_loss=0.4770, val_loss=0.5028, train_acc=0.8383, val_acc=0.8320
# Epoch 04: train_loss=0.4159, val_loss=0.4811, train_acc=0.8556, val_acc=0.8396
# Epoch 05: train_loss=0.3724, val_loss=0.4641, train_acc=0.8667, val_acc=0.8437
# Epoch 06: train_loss=0.3384, val_loss=0.4626, train_acc=0.8756, val_acc=0.8468
# Epoch 07: train_loss=0.3082, val_loss=0.4586, train_acc=0.8854, val_acc=0.8504
# Epoch 08: train_loss=0.2846, val_loss=0.4714, train_acc=0.8921, val_acc=0.8474
# Epoch 09: train_loss=0.2623, val_loss=0.4874, train_acc=0.8992, val_acc=0.8467
# Epoch 10: train_loss=0.2409, val_loss=0.4807, train_acc=0.9049, val_acc=0.8518
# Epoch 11: train_loss=0.2256, val_loss=0.5033, train_acc=0.9101, val_acc=0.8483
# Epoch 12: train_loss=0.2104, val_loss=0.5357, train_acc=0.9149, val_acc=0.8426
# Epoch 13: train_loss=0.1977, val_loss=0.5352, train_acc=0.9192, val_acc=0.8429
# Epoch 14: train_loss=0.1838, val_loss=0.5666, train_acc=0.9244, val_acc=0.8420
# Epoch 15: train_loss=0.1759, val_loss=0.5794, train_acc=0.9276, val_acc=0.8403
# Epoch 16: train_loss=0.1653, val_loss=0.5933, train_acc=0.9309, val_acc=0.8501
# Epoch 17: train_loss=0.1578, val_loss=0.6060, train_acc=0.9349, val_acc=0.8456
# Epoch 18: train_loss=0.1506, val_loss=0.6476, train_acc=0.9375, val_acc=0.8410
# Epoch 19: train_loss=0.1436, val_loss=0.6686, train_acc=0.9398, val_acc=0.8430
# Epoch 20: train_loss=0.1382, val_loss=0.6886, train_acc=0.9422, val_acc=0.8392
#
# === E2 ===
# dropout=0.3, bn=False, opt=Adam, lr=0.001, momentum=0.0, wd=0.0, early_stopping=False
# Epoch 01: train_loss=1.2858, val_loss=0.7094, train_acc=0.6253, val_acc=0.7808
# Epoch 02: train_loss=0.7444, val_loss=0.5920, train_acc=0.7614, val_acc=0.8062
# Epoch 03: train_loss=0.6370, val_loss=0.5130, train_acc=0.7918, val_acc=0.8322
# Epoch 04: train_loss=0.5758, val_loss=0.4843, train_acc=0.8068, val_acc=0.8386
# Epoch 05: train_loss=0.5364, val_loss=0.4732, train_acc=0.8181, val_acc=0.8410
# Epoch 06: train_loss=0.5122, val_loss=0.4570, train_acc=0.8228, val_acc=0.8426
# Epoch 07: train_loss=0.4893, val_loss=0.4484, train_acc=0.8312, val_acc=0.8455
# Epoch 08: train_loss=0.4684, val_loss=0.4491, train_acc=0.8361, val_acc=0.8475
# Epoch 09: train_loss=0.4584, val_loss=0.4386, train_acc=0.8381, val_acc=0.8497
# Epoch 10: train_loss=0.4436, val_loss=0.4395, train_acc=0.8419, val_acc=0.8497
# Epoch 11: train_loss=0.4334, val_loss=0.4354, train_acc=0.8448, val_acc=0.8515
# Epoch 12: train_loss=0.4213, val_loss=0.4325, train_acc=0.8489, val_acc=0.8536
# Epoch 13: train_loss=0.4134, val_loss=0.4313, train_acc=0.8508, val_acc=0.8566
# Epoch 14: train_loss=0.4041, val_loss=0.4282, train_acc=0.8523, val_acc=0.8541
# Epoch 15: train_loss=0.3972, val_loss=0.4362, train_acc=0.8551, val_acc=0.8543
# Epoch 16: train_loss=0.3921, val_loss=0.4284, train_acc=0.8553, val_acc=0.8569
# Epoch 17: train_loss=0.3858, val_loss=0.4240, train_acc=0.8571, val_acc=0.8595
# Epoch 18: train_loss=0.3806, val_loss=0.4287, train_acc=0.8592, val_acc=0.8569
# Epoch 19: train_loss=0.3729, val_loss=0.4322, train_acc=0.8618, val_acc=0.8546
# Epoch 20: train_loss=0.3721, val_loss=0.4318, train_acc=0.8603, val_acc=0.8568
#
# === E3 ===
# dropout=0.0, bn=True, opt=Adam, lr=0.001, momentum=0.0, wd=0.0, early_stopping=False
# Epoch 01: train_loss=0.8458, val_loss=0.5593, train_acc=0.7518, val_acc=0.8163
# Epoch 02: train_loss=0.4884, val_loss=0.4912, train_acc=0.8338, val_acc=0.8339
# Epoch 03: train_loss=0.4097, val_loss=0.4609, train_acc=0.8552, val_acc=0.8447
# Epoch 04: train_loss=0.3629, val_loss=0.4485, train_acc=0.8694, val_acc=0.8469
# Epoch 05: train_loss=0.3275, val_loss=0.4574, train_acc=0.8793, val_acc=0.8421
# Epoch 06: train_loss=0.2975, val_loss=0.4480, train_acc=0.8878, val_acc=0.8489
# Epoch 07: train_loss=0.2745, val_loss=0.4491, train_acc=0.8949, val_acc=0.8516
# Epoch 08: train_loss=0.2547, val_loss=0.4628, train_acc=0.9015, val_acc=0.8472
# Epoch 09: train_loss=0.2371, val_loss=0.4555, train_acc=0.9064, val_acc=0.8517
# Epoch 10: train_loss=0.2220, val_loss=0.4746, train_acc=0.9113, val_acc=0.8525
# Epoch 11: train_loss=0.2054, val_loss=0.4949, train_acc=0.9175, val_acc=0.8476
# Epoch 12: train_loss=0.1966, val_loss=0.4988, train_acc=0.9201, val_acc=0.8513
# Epoch 13: train_loss=0.1842, val_loss=0.5122, train_acc=0.9253, val_acc=0.8492
# Epoch 14: train_loss=0.1768, val_loss=0.5284, train_acc=0.9286, val_acc=0.8422
# Epoch 15: train_loss=0.1653, val_loss=0.5215, train_acc=0.9324, val_acc=0.8516
# Epoch 16: train_loss=0.1570, val_loss=0.5524, train_acc=0.9366, val_acc=0.8459
# Epoch 17: train_loss=0.1506, val_loss=0.5541, train_acc=0.9384, val_acc=0.8492
# Epoch 18: train_loss=0.1432, val_loss=0.5677, train_acc=0.9414, val_acc=0.8500
# Epoch 19: train_loss=0.1407, val_loss=0.5774, train_acc=0.9421, val_acc=0.8508
# Epoch 20: train_loss=0.1338, val_loss=0.5972, train_acc=0.9452, val_acc=0.8501
# Лучший эксперимент регуляризации: E2
#
# === E4 ===
# dropout=0.3, bn=False, opt=Adam, lr=0.001, momentum=0.0, wd=0.0, early_stopping=True
# Epoch 01: train_loss=1.2885, val_loss=0.7078, train_acc=0.6244, val_acc=0.7806
# Epoch 02: train_loss=0.7470, val_loss=0.5836, train_acc=0.7625, val_acc=0.8125
# Epoch 03: train_loss=0.6353, val_loss=0.5157, train_acc=0.7911, val_acc=0.8302
# Epoch 04: train_loss=0.5750, val_loss=0.4964, train_acc=0.8074, val_acc=0.8316
# Epoch 05: train_loss=0.5421, val_loss=0.4718, train_acc=0.8162, val_acc=0.8438
# Epoch 06: train_loss=0.5092, val_loss=0.4616, train_acc=0.8249, val_acc=0.8443
# Epoch 07: train_loss=0.4861, val_loss=0.4532, train_acc=0.8321, val_acc=0.8494
# Epoch 08: train_loss=0.4724, val_loss=0.4390, train_acc=0.8349, val_acc=0.8524
# Epoch 09: train_loss=0.4576, val_loss=0.4363, train_acc=0.8379, val_acc=0.8520
# Epoch 10: train_loss=0.4435, val_loss=0.4389, train_acc=0.8415, val_acc=0.8543
# Epoch 11: train_loss=0.4349, val_loss=0.4394, train_acc=0.8442, val_acc=0.8504
# Epoch 12: train_loss=0.4239, val_loss=0.4402, train_acc=0.8464, val_acc=0.8533
# Epoch 13: train_loss=0.4144, val_loss=0.4290, train_acc=0.8495, val_acc=0.8562
# Epoch 14: train_loss=0.4059, val_loss=0.4332, train_acc=0.8520, val_acc=0.8537
# Epoch 15: train_loss=0.3977, val_loss=0.4262, train_acc=0.8530, val_acc=0.8583
# Epoch 16: train_loss=0.3906, val_loss=0.4267, train_acc=0.8575, val_acc=0.8584
# Epoch 17: train_loss=0.3885, val_loss=0.4215, train_acc=0.8567, val_acc=0.8597
# Epoch 18: train_loss=0.3825, val_loss=0.4240, train_acc=0.8594, val_acc=0.8585
# Epoch 19: train_loss=0.3787, val_loss=0.4295, train_acc=0.8604, val_acc=0.8581
# Epoch 20: train_loss=0.3721, val_loss=0.4298, train_acc=0.8617, val_acc=0.8582

# %%
best_model = MLP(
    hidden_sizes=(512, 256),
    dropout_p=0.3,
    use_bn=False
).to(device)

best_model.load_state_dict(torch.load("artifacts/best_model.pt"))
best_model.eval()

criterion = nn.CrossEntropyLoss()
test_loss, test_acc = evaluate(best_model, test_loader, criterion)

print("Final test accuracy:", test_acc)
print("Final test loss:", test_loss)
# Out:
# Final test accuracy: 0.8556382978723405
# Final test loss: 0.45088991352852353

# %% [markdown]
# Часть B (S09)

# %%
results["O1"] = run_experiment(
    "O1",
    dropout=0.3 if best_reg_exp == "E2" else 0.0,
    use_bn=(best_reg_exp == "E3"),
    optimizer_name="Adam",
    lr=1e-1,
    max_epochs=8,
)

results["O2"] = run_experiment(
    "O2",
    dropout=0.3 if best_reg_exp == "E2" else 0.0,
    use_bn=(best_reg_exp == "E3"),
    optimizer_name="Adam",
    lr=1e-5,
    max_epochs=8,
)

results["O3"] = run_experiment(
    "O3",
    dropout=0.3 if best_reg_exp == "E2" else 0.0,
    use_bn=(best_reg_exp == "E3"),
    optimizer_name="SGD",
    lr=1e-2,
    momentum=0.9,
    weight_decay=1e-4,
    max_epochs=15,
)
# Out:
# === O1 ===
# dropout=0.3, bn=False, opt=Adam, lr=0.1, momentum=0.0, wd=0.0, early_stopping=False
# Epoch 01: train_loss=5.0768, val_loss=3.8711, train_acc=0.0289, val_acc=0.0219
# Epoch 02: train_loss=3.8723, val_loss=3.8651, train_acc=0.0217, val_acc=0.0205
# Epoch 03: train_loss=3.8643, val_loss=3.8662, train_acc=0.0210, val_acc=0.0215
# Epoch 04: train_loss=3.8647, val_loss=3.8659, train_acc=0.0203, val_acc=0.0205
# Epoch 05: train_loss=3.8655, val_loss=3.8639, train_acc=0.0210, val_acc=0.0217
# Epoch 06: train_loss=3.8651, val_loss=3.8634, train_acc=0.0209, val_acc=0.0200
# Epoch 07: train_loss=3.8646, val_loss=3.8645, train_acc=0.0202, val_acc=0.0215
# Epoch 08: train_loss=3.8651, val_loss=3.8616, train_acc=0.0210, val_acc=0.0200
#
# === O2 ===
# dropout=0.3, bn=False, opt=Adam, lr=1e-05, momentum=0.0, wd=0.0, early_stopping=False
# Epoch 01: train_loss=3.7736, val_loss=3.6228, train_acc=0.0973, val_acc=0.2692
# Epoch 02: train_loss=3.3751, val_loss=3.0270, train_acc=0.2432, val_acc=0.4039
# Epoch 03: train_loss=2.8271, val_loss=2.4873, train_acc=0.3261, val_acc=0.4680
# Epoch 04: train_loss=2.4396, val_loss=2.1433, train_acc=0.3807, val_acc=0.5096
# Epoch 05: train_loss=2.1961, val_loss=1.9257, train_acc=0.4176, val_acc=0.5366
# Epoch 06: train_loss=2.0303, val_loss=1.7775, train_acc=0.4498, val_acc=0.5608
# Epoch 07: train_loss=1.9160, val_loss=1.6725, train_acc=0.4732, val_acc=0.5774
# Epoch 08: train_loss=1.8243, val_loss=1.5933, train_acc=0.4951, val_acc=0.5914
#
# === O3 ===
# dropout=0.3, bn=False, opt=SGD, lr=0.01, momentum=0.9, wd=0.0001, early_stopping=False
# Epoch 01: train_loss=2.2466, val_loss=1.2450, train_acc=0.3999, val_acc=0.6465
# Epoch 02: train_loss=1.1923, val_loss=0.9100, train_acc=0.6493, val_acc=0.7322
# Epoch 03: train_loss=0.9519, val_loss=0.7572, train_acc=0.7120, val_acc=0.7717
# Epoch 04: train_loss=0.8273, val_loss=0.6724, train_acc=0.7454, val_acc=0.7898
# Epoch 05: train_loss=0.7483, val_loss=0.6190, train_acc=0.7652, val_acc=0.8046
# Epoch 06: train_loss=0.6986, val_loss=0.5809, train_acc=0.7794, val_acc=0.8174
# Epoch 07: train_loss=0.6558, val_loss=0.5617, train_acc=0.7901, val_acc=0.8203
# Epoch 08: train_loss=0.6261, val_loss=0.5346, train_acc=0.7975, val_acc=0.8283
# Epoch 09: train_loss=0.5995, val_loss=0.5216, train_acc=0.8052, val_acc=0.8303
# Epoch 10: train_loss=0.5794, val_loss=0.5000, train_acc=0.8101, val_acc=0.8350
# Epoch 11: train_loss=0.5561, val_loss=0.4906, train_acc=0.8159, val_acc=0.8386
# Epoch 12: train_loss=0.5445, val_loss=0.4825, train_acc=0.8186, val_acc=0.8394
# Epoch 13: train_loss=0.5298, val_loss=0.4716, train_acc=0.8224, val_acc=0.8405
# Epoch 14: train_loss=0.5159, val_loss=0.4630, train_acc=0.8279, val_acc=0.8465
# Epoch 15: train_loss=0.5024, val_loss=0.4563, train_acc=0.8309, val_acc=0.8483

# %% [markdown]
# #### Артефакты

# %%
best_config = {
    "dataset": "EMNIST Balanced",
    "seed": SEED,
    "model": "MLP(28*28 → 512 → 256 → 47)",
    "dropout": 0.3 if best_reg_exp == "E2" else 0.0,
    "batchnorm": bool(best_reg_exp == "E3"),
    "optimizer": "Adam",
    "lr": 1e-3,
    "early_stopping": True,
    "patience": 5,
}

with open("artifacts/best_config.json", "w") as f:
    json.dump(best_config, f, indent=4)

# %%
with open("artifacts/runs.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow([
        "experiment_id", "dataset", "seed", "model_summary",
        "optimizer", "lr", "momentum", "weight_decay",
        "epochs_trained", "best_val_accuracy",
    ])

    for exp_id, (val_acc, _, hist) in results.items():
        best_val_loss = min(hist["val_loss"])
        if exp_id.startswith("E"):
            opt = "Adam"; lr = 1e-3; momentum = 0.0; wd = 0.0
        elif exp_id == "O1":
            opt = "Adam"; lr = 1e-1; momentum = 0.0; wd = 0.0
        elif exp_id == "O2":
            opt = "Adam"; lr = 1e-5; momentum = 0.0; wd = 0.0
        else:
            opt = "SGD"; lr = 1e-2; momentum = 0.9; wd = 1e-4

        writer.writerow([
            exp_id,
            "EMNIST Balanced",
            SEED,
            "MLP 512-256-47",
            opt,
            lr,
            momentum,
            wd,
            len(hist["train_loss"]),
            val_acc,
            best_val_loss,
        ])

# %% [markdown]
# Графики

# %%
def plot_history(history, title, filename):
    plt.figure(figsize=(10,4))

    plt.subplot(1,2,1)
    plt.plot(history["train_loss"], label="train")
    plt.plot(history["val_loss"], label="val")
    plt.title("Loss")
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(history["train_acc"], label="train")
    plt.plot(history["val_acc"], label="val")
    plt.title("Accuracy")
    plt.legend()

    plt.suptitle(title)
    plt.tight_layout()
    plt.savefig(filename)
    plt.close()

plot_history(results["E4"][2], "Best run (E4)", "artifacts/figures/curves_best.png")
plot_history(results["O1"][2], "LR too big (O1)", "artifacts/figures/curves_lr_extremes_O1.png")
plot_history(results["O2"][2], "LR too small (O2)", "artifacts/figures/curves_lr_extremes_O2.png")

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# O1
axes[0].plot(results["O1"][2]["train_loss"], label="train")
axes[0].plot(results["O1"][2]["val_loss"], label="val")
axes[0].set_title("O1: LR too big")
axes[0].legend()

# O2
axes[1].plot(results["O2"][2]["train_loss"], label="train")
axes[1].plot(results["O2"][2]["val_loss"], label="val")
axes[1].set_title("O2: LR too small")
axes[1].legend()

plt.tight_layout()
plt.savefig("artifacts/figures/curves_lr_extremes.png", dpi=200)
plt.show()
